# %% [markdown]
# # Mini-brief ML #05 — Random Forest
#
# > Objectif : entraîner, lire les **importances**, utiliser le **score OOB**, montrer le gain de stabilité vs un arbre seul.
#
# Dataset : `load_breast_cancer`.

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

X, y = load_breast_cancer(return_X_y=True, as_frame=True)
Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=.25, stratify=y, random_state=42)

# %% [markdown]
# ## 1. Forêt vs arbre seul (réduction de variance)

# %%
rf = RandomForestClassifier(n_estimators=300, oob_score=True, random_state=42).fit(Xtr, ytr)
dt = DecisionTreeClassifier(random_state=42).fit(Xtr, ytr)
print(f'arbre seul test : {dt.score(Xte,yte):.3f}')
print(f'forêt test      : {rf.score(Xte,yte):.3f}  | OOB : {rf.oob_score_:.3f}')

# %% [markdown]
# ## 2. Le geste clé — les variables qui comptent

# %%
imp = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)
print(imp.head(8))

# %% [markdown]
# ## 3. 🎯 À toi de jouer
# Fais varier `n_estimators` (10, 50, 300) et `max_features` ('sqrt', None). Le score OOB confirme-t-il le score test ?

# %%
# TODO : boucle sur n_estimators / max_features
# TODO : comparer oob_score_ et score(Xte, yte)

# %% [markdown]
# ## ✅ Critères
# - [ ] Comparaison arbre vs forêt
# - [ ] Importances lues
# - [ ] OOB utilisé comme validation gratuite
#
# **Pièges** : trop peu d'arbres (instable) · lire les importances comme de la causalité.
